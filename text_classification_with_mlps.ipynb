# %% [markdown]
# # Text Classification w. MLPs
#
# > *Text Analytics*
# > *MSc in Data Science, Department of Informatics*
# > *Athens University of Economics and Business*
#
# ---
#
# <p style='text-align: justify;'>Develop a sentiment classifier for a kind of texts of your choice (e.g., tweets, product or movie reviews). Use an existing sentiment analysis dataset with at least two classes (e.g., positive/negative or positive/negative/neutral). The classes should be mutually exclusive, i.e., this is a single-label multi-class classification problem.</p>
#
# <p style='text-align: justify;'>Repeat the project implemented in <a href="https://github.com/sapaladas/text_classification_with_basic_models"><i>text_classification_with_basic_models</i></a> repository, now using an MLP classifier implemented in Keras/TensorFlow or PyTorch. Tune the hyper-parameters (e.g., number of hidden layers, dropoit probability) on the development subset of your dataset. Monitor the performance of the MLP during training to decide how many epochs to use. Include experimental results of a baseline majority classifier, as well as experimental results of the best classifier from <a href="https://github.com/sapaladas/text_classification_with_basic_models"><i>text_classification_with_basic_models</i></a> repository, now treated as a second baseline. For each classifier:</p>
#
# <ul>
#     <li>Calculate (macro-averaged) precision, recall, F1 both for the training and test subsets</li>
#     <li>Calculate and plot the confusion matrices both for the training and test subsets</li>
#     <li>Calculate and plot the precision-recall AUC scores both for the training and test subsets</li>
#     <li>Calculate and plot the curves showing the accuracy and loss on training data as a function of epochs</li>
# </ul>
#
# ## *Table of Contents*
#
# - [*1. Libraries*](#libraries)
# - [*2. Data*](#data)
# - [*3. Descriptive Statistics*](#descriptive_statistics)
# - [*4. Data Cleansing*](#data_cleansing)
# - [*5. Train Validation Test Split*](#train_valid_test_split)
# - [*6. Text Vectorization*](#text_vectorization)
# - [*7. Dimensionality Reduction*](#dimensionality_reduction)
# - [*8. Baseline Results*](#baseline_results)
# - [*9. MLP Hyperparameter Tuning*](#tuning)
# - [*10. Classification Results*](#results)
#
# ---

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import unidecode
import contractions
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from datetime import datetime

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

from sklearn.model_selection import cross_validate, StratifiedKFold, RandomizedSearchCV
from sklearn.dummy import DummyClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from lightgbm import LGBMClassifier

from sklearn.metrics import precision_score, recall_score, f1_score, precision_recall_curve, auc, accuracy_score
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import learning_curve

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from tensorflow.keras.layers import InputLayer

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data <a class='anchor' id='data'></a>
#
# - The data were acquired from [kaggle](https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews) and is the ["Large Movie Review Dataset"](https://ai.stanford.edu/~amaas/data/sentiment/) by Andrew Maas
# - This is a dataset for binary sentiment classification which contains 50K movie reviews
# - The reviews are labelled either as positive or negative
# - The two classes are balanced with each containing 25K reviews
#
# > *@InProceedings{maas-EtAl:2011:ACL-HLT2011,*
# >   *author    = {Maas, Andrew L.  and  Daly, Raymond E.  and  Pham, Peter T.  and  Huang, Dan  and  Ng, Andrew Y.  and  Potts, Christopher},*
# >   *title     = {Learning Word Vectors for Sentiment Analysis},*
# >   *booktitle = {Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies},*
# >   *month     = {June},*
# >   *year      = {2011},*
# >   *address   = {Portland, Oregon, USA},*
# >   *publisher = {Association for Computational Linguistics},*
# >   *pages     = {142--150},*
# >   *url       = {http://www.aclweb.org/anthology/P11-1015}*
# > }
#
# ##### *Read the data*

# %%
# read the dataset
raw = pd.read_csv('./data/IMDB Dataset.csv')

# shape
print(f'raw.shape: {raw.shape}', end='\n\n')

# preview
print(raw.head())
# Out:
# raw.shape: (50000, 2)
#
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# ##### *Convert target column `sentiment` from string to binary*

# %%
# create a copy of raw data to work with
df = raw.copy()

# convert target column from string to binary
df.sentiment = df.sentiment.apply(lambda x: 0 if x == 'negative' else 1)

# count positive vs negative reviews
print(f'There are {len(df[df.sentiment == 0])} negative and {len(df[df.sentiment == 1])} positive reviews.', end='\n\n')

# preview the first 5 reviews
for i in range(5):
    print(f'{i+1} - {df.review[i]}', end='\n\n')
# Out:
# There are 25000 negative and 25000 positive reviews.
#
# 1 - One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the fact that it goes where other shows wouldn't dare. Forget pretty pictures painted for mainstream audiences, forget charm, forget romance...OZ doesn't mess around. The first episode I ever saw struck me as so nasty it was surreal, I couldn't say I was ready for it, but as I watched more, I developed a taste for Oz, and got accustomed to the high levels of graphic violence. Not just violence, but injustice (crooked guards who'll be sold out for a nickel, inmates who'll kill on order and get away with it, well mannered, middle class inmates being turned into prison bitches due to their lack of street skills or prison experience) Watching Oz, you may become comfortable with what is uncomfortable viewing....thats if you can get in touch with your darker side.
#
# 2 - A wonderful little production. <br /><br />The filming technique is very unassuming- very old-time-BBC fashion and gives a comforting, and sometimes discomforting, sense of realism to the entire piece. <br /><br />The actors are extremely well chosen- Michael Sheen not only "has got all the polari" but he has all the voices down pat too! You can truly see the seamless editing guided by the references to Williams' diary entries, not only is it well worth the watching but it is a terrificly written and performed piece. A masterful production about one of the great master's of comedy and his life. <br /><br />The realism really comes home with the little things: the fantasy of the guard which, rather than use the traditional 'dream' techniques remains solid then disappears. It plays on our knowledge and our senses, particularly with the scenes concerning Orton and Halliwell and the sets (particularly of their flat with Halliwell's murals decorating every surface) are terribly well done.
#
# 3 - I thought this was a wonderful way to spend time on a too hot summer weekend, sitting in the air conditioned theater and watching a light-hearted comedy. The plot is simplistic, but the dialogue is witty and the characters are likable (even the well bread suspected serial killer). While some may be disappointed when they realize this is not Match Point 2: Risk Addiction, I thought it was proof that Woody Allen is still fully in control of the style many of us have grown to love.<br /><br />This was the most I'd laughed at one of Woody's comedies in years (dare I say a decade?). While I've never been impressed with Scarlet Johanson, in this she managed to tone down her "sexy" image and jumped right into a average, but spirited young woman.<br /><br />This may not be the crown jewel of his career, but it was wittier than "Devil Wears Prada" and more interesting than "Superman" a great comedy to go see with friends.
#
# 4 - Basically there's a family where a little boy (Jake) thinks there's a zombie in his closet & his parents are fighting all the time.<br /><br />This movie is slower than a soap opera... and suddenly, Jake decides to become Rambo and kill the zombie.<br /><br />OK, first of all when you're going to make a film you must Decide if its a thriller or a drama! As a drama the movie is watchable. Parents are divorcing & arguing like in real life. And then we have Jake with his closet which totally ruins all the film! I expected to see a BOOGEYMAN similar movie, and instead i watched a drama with some meaningless thriller spots.<br /><br />3 out of 10 just for the well playing parents & descent dialogs. As for the shots with Jake: just ignore them.
#
# 5 - Petter Mattei's "Love in the Time of Money" is a visually stunning film to watch. Mr. Mattei offers us a vivid portrait about human relations. This is a movie that seems to be telling us what money, power and success do to people in the different situations we encounter. <br /><br />This being a variation on the Arthur Schnitzler's play about the same theme, the director transfers the action to the present time New York where all these different characters meet and connect. Each one is connected in one way, or another to the next person, but no one seems to know the previous point of contact. Stylishly, the film has a sophisticated luxurious look. We are taken to see how these people live and the world they live in their own habitat.<br /><br />The only thing one gets out of all these souls in the picture is the different stages of loneliness each one inhabits. A big city is not exactly the best place in which human relations find sincere fulfillment, as one discerns is the case with most of the people we encounter.<br /><br />The acting is good under Mr. Mattei's direction. Steve Buscemi, Rosario Dawson, Carol Kane, Michael Imperioli, Adrian Grenier, and the rest of the talented cast, make these characters come alive.<br /><br />We wish Mr. Mattei good luck and await anxiously for his next work.

# %% [markdown]
# ## Descriptive Statistics <a class='anchor' id='descriptive_statistics'></a>
#
# - In this step we will do a brief analysis to extract some basic descriptive statistics about the reviews
# - Specifically, we will calculate the vocabulary size and the avg/min/max review length for each class
#
# ##### *Define function to obtain some descriptive statistics*

# %%
def descriptive_statistics(df):
    
    # get the vocabulary size
    # aka number of unique words appeared in the reviews
    vocabulary_size = len(list(set(' '.join(df.review).split())))
    
    # get the length of each review
    df['review_length'] = df.review.apply(lambda x: len(x))
    
    # get the avg, min, max review length (overall)
    avg_len = int(np.mean(df.review_length))
    min_len = df.review_length.min()
    max_len = df.review_length.max()
    
    # get the avg, min, max review length (positive class)
    avg_len_pos = int(np.mean(df[df.sentiment == 1].review_length))
    min_len_pos = df[df.sentiment == 1].review_length.min()
    max_len_pos = df[df.sentiment == 1].review_length.max()
    
    # get the avg, min, max review length (negative class)
    avg_len_neg = int(np.mean(df[df.sentiment == 0].review_length))
    min_len_neg = df[df.sentiment == 0].review_length.min()
    max_len_neg = df[df.sentiment == 0].review_length.max()
    
    print('='*117)
    print('Vocabulary', end='\n\n')
    print(f'There are {vocabulary_size} unique words.')
    print('='*117)
    print('Reviews Statistics', end='\n\n')    
    print(f'Positive Reviews')
    print(f'- Average Length: {avg_len_pos}')
    print(f'- Minimum Length: {min_len_pos}')
    print(f'- Maximum Length: {max_len_pos}', end='\n\n')
    print(f'Negative Reviews')
    print(f'- Average Length: {avg_len_neg}')
    print(f'- Minimum Length: {min_len_neg}')
    print(f'- Maximum Length: {max_len_neg}', end='\n\n')
    print('='*117)
    
    # create figure
    fig, (ax1,ax2) = plt.subplots(1,2,figsize=(12,4),dpi=100,facecolor='white')
    # plot positive reviews length distribution
    sns.kdeplot(x=df[df.sentiment == 1].review_length, shade=True, color='navy', ax=ax1)
    ax1.axvline(avg_len_pos, linestyle='--', color='black')
    ax1.set_xlabel('Number of Words')
    ax1.set_ylabel(None)
    ax1.set_yticks([])
    ax1.set_title('Positive Reviews Length Distribution')
    # plot negative reviews length distribution
    sns.kdeplot(x=df[df.sentiment == 0].review_length, shade=True, color='green', ax=ax2)
    ax2.axvline(avg_len_neg, linestyle='--', color='black')
    ax2.set_xlabel('Number of Words')
    ax2.set_ylabel(None)
    ax2.set_yticks([])
    ax2.set_title('Negative Reviews Length Distribution')
    plt.tight_layout(pad=3)
    plt.savefig(f'./images/reviews_length_distribution.svg')
    plt.show()
    
    return

# execute function
_ = descriptive_statistics(df)
# Out:
# =====================================================================================================================
# Vocabulary
#
# There are 438729 unique words.
# =====================================================================================================================
# Reviews Statistics
#
# Positive Reviews
# - Average Length: 1324
# - Minimum Length: 65
# - Maximum Length: 13704
#
# Negative Reviews
# - Average Length: 1294
# - Minimum Length: 32
# - Maximum Length: 8969
#
# =====================================================================================================================

# %% [markdown]
# ## Data Cleansing <a class='anchor' id='data_cleansing'></a>
#
# - Before we proceed with the next steps, we first need to clean our data
# - Therefore, we will apply the following preprocessing steps to the reviews:
#     - Convert to lowercase
#     - Replace accented characters
#     - Expand contractions
#     - Remove HTML tags
#     - Replace non alphabet characters with space
#     - Remove stopwords
#     - Remove words with less than 4 characters
#     - Perform stemming
#
# ##### *Define function to clean and preprocess the reviews*

# %%
def preprocess_data(review):

    # convert to lowercase
    review = review.strip().lower()

    # replace accented characters
    review = unidecode.unidecode(review)

    # expand contractions
    review = contractions.fix(review)

    # remove html tags
    review = re.sub(r'<.*?>', ' ', review)

    # replace non alphabet characters with space
    review = re.sub(r'[^a-z]', ' ', review)

    # split into words
    review = review.split()

    # remove stopwords
    review = [word for word in review if word not in stopwords.words('english')]

    # remove words with less than 3 chars
    review = [word for word in review if len(word) > 3]

    # stemming
    stemmer = PorterStemmer()
    review = [stemmer.stem(word) for word in review]

    # join the word to form the sentence
    review = ' '.join(review)

    return review

# starting time
start_time = datetime.now()

# execute function
df.review = df.review.apply(preprocess_data)

# end time
end_time = datetime.now()

print(f'Elapsed time: {end_time - start_time}', end='\n\n')

# preview the first 5 reviews
for i in range(5):
    print(f'{i+1} - {df.review[i]}', end='\n\n')
# Out:
# Elapsed time: 0:14:39.052306
#
# 1 - review mention watch episod hook right exactli happen first thing struck brutal unflinch scene violenc right word trust show faint heart timid show pull punch regard drug violenc hardcor classic word call nicknam given oswald maximum secur state penitentari focus mainli emerald citi experiment section prison cell glass front face inward privaci high agenda citi home mani aryan muslim gangsta latino christian italian irish scuffl death stare dodgi deal shadi agreement never away would main appeal show fact goe show would dare forget pretti pictur paint mainstream audienc forget charm forget romanc mess around first episod ever struck nasti surreal could readi watch develop tast accustom high level graphic violenc violenc injustic crook guard sold nickel inmat kill order away well manner middl class inmat turn prison bitch lack street skill prison experi watch becom comfort uncomfort view touch darker side
#
# 2 - wonder littl product film techniqu unassum time fashion give comfort sometim discomfort sens realism entir piec actor extrem well chosen michael sheen polari voic truli seamless edit guid refer william diari entri well worth watch terrificli written perform piec master product great master comedi life realism realli come home littl thing fantasi guard rather tradit dream techniqu remain solid disappear play knowledg sens particularli scene concern orton halliwel set particularli flat halliwel mural decor everi surfac terribl well done
#
# 3 - thought wonder spend time summer weekend sit condit theater watch light heart comedi plot simplist dialogu witti charact likabl even well bread suspect serial killer disappoint realiz match point risk addict thought proof woodi allen still fulli control style mani grown love would laugh woodi comedi year dare decad never impress scarlet johanson manag tone sexi imag jump right averag spirit young woman crown jewel career wittier devil wear prada interest superman great comedi friend
#
# 4 - basic famili littl jake think zombi closet parent fight time movi slower soap opera suddenli jake decid becom rambo kill zombi first go make film must decid thriller drama drama movi watchabl parent divorc argu like real life jake closet total ruin film expect boogeyman similar movi instead watch drama meaningless thriller spot well play parent descent dialog shot jake ignor
#
# 5 - petter mattei love time money visual stun film watch mattei offer vivid portrait human relat movi seem tell money power success peopl differ situat encount variat arthur schnitzler play theme director transfer action present time york differ charact meet connect connect anoth next person seem know previou point contact stylishli film sophist luxuri look taken peopl live world live habitat thing get soul pictur differ stage loneli inhabit citi exactli best place human relat find sincer fulfil discern case peopl encount act good mattei direct steve buscemi rosario dawson carol kane michael imperioli adrian grenier rest talent cast make charact come aliv wish mattei good luck await anxious next work

# %% [markdown]
# ## Train Validation Test Split <a class='anchor' id='train_valid_test_split'></a>
#
# - Next, we will split the data into *training* set $(70\%)$, *validation* set $(15\%)$ and *test* set $(15\%)$
# - We, also, use stratified split to keep the same distribution of positive and negative reviews between the three subsets
#
# ##### *Define a function to split the data into three subsets*

# %%
def train_validation_test_split_reviews(dataset):

    # define x and y
    x = dataset.review
    y = dataset.sentiment

    # split into train - validation + test sets
    x_train, x_valid_test, y_train, y_valid_test = train_test_split(x,
                                                                    y,
                                                                    test_size=0.3,
                                                                    shuffle=True,
                                                                    stratify=y,
                                                                    random_state=1)
    
    # split into validation - test sets
    x_valid, x_test, y_valid, y_test = train_test_split(x_valid_test,
                                                        y_valid_test,
                                                        test_size=0.5,
                                                        shuffle=True,
                                                        stratify=y_valid_test,
                                                        random_state=1)
    
    
    # preview the sizes
    print(f'len(reviews):   {len(dataset)}')
    print(f'len(train_set): {len(x_train)}')
    print(f'len(valid_set): {len(x_valid)}')
    print(f'len(test_set):  {len(x_test)}')

    return x_train, x_valid, x_test, y_train, y_valid, y_test

# execute function
x_train, x_valid, x_test, y_train, y_valid, y_test = train_validation_test_split_reviews(df)
# Out:
# len(reviews):   50000
# len(train_set): 35000
# len(valid_set): 7500
# len(test_set):  7500

# %% [markdown]
# ## Text Vectorization <a class='anchor' id='text_vectorization'></a>
#
# - The next step is to vectorize the reviews into term-document matrices using TF-IDF
# - TF-IDF is a measure that quantifies the importance or relevance of string representations in a document amongst a collection of documents (aka corpus)
# - In our case, we will extract the vectors for both unigrams and bigrams and consider only the top $10000$ features
# - Finally, we will apply sublinear tf scaling, i.e. replace tf with $1 + log(tf)$ (converting tf-idf to wf-idf)
#
# ##### *Define a function to perform text vectorization*

# %%
def text_vectorization(x_train, x_valid, x_test):

    # initialize the TFIDF vectorizer
    vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=10000, sublinear_tf=True)
    
    # vectorize the reviews in train and test sets
    x_train_tfidf = vectorizer.fit_transform(x_train)
    x_valid_tfidf = vectorizer.transform(x_valid)
    x_test_tfidf = vectorizer.transform(x_test)

    return x_train_tfidf, x_valid_tfidf, x_test_tfidf

# execute function
x_train_tfidf, x_valid_tfidf, x_test_tfidf = text_vectorization(x_train, x_valid, x_test)

# %% [markdown]
# ## Dimensionality Reduction <a class='anchor' id='dimensionality_reduction'></a>
#
# - In addition, we will perform dimensionality reduction on the vectors generated from the previous step to reduce the number of features
# - In particular, we will use the Truncated SVD transformer which performs linear dimensionality reduction and works well with sparse matrices
# - Due to time and resource limitations, we will reduce the dimensionality to $2000$ features
# - This results in an explained variance ratio of $60\%$ of our initial feature vectors
#
# ##### *Define a function to perform dimensionality reduction*

# %%
def dimensionality_reduction(x_train_tfidf, x_valid_tfidf, x_test_tfidf):

    # initialize the truncated SVD transformer
    n_components = 2000
    svd = TruncatedSVD(n_components=n_components, random_state=1)

    # decompose the values
    # in training, validation and test sets
    x_train_svd = svd.fit_transform(x_train_tfidf)
    x_valid_svd = svd.transform(x_valid_tfidf)
    x_test_svd = svd.transform(x_test_tfidf)

    # print the explained variance ratio
    print(f'The explained variance ratio with {n_components} components is {svd.explained_variance_ratio_.sum():.3}.', end='\n\n')

    return x_train_svd, x_valid_svd, x_test_svd

# starting time
start_time = datetime.now()

# execute function
x_train_svd, x_valid_svd, x_test_svd = dimensionality_reduction(x_train_tfidf, x_valid_tfidf, x_test_tfidf)

# end time
end_time = datetime.now()

print(f'Elapsed time: {end_time - start_time}')
# Out:
# The explained variance ratio with 2000 components is 0.598.
#
# Elapsed time: 0:01:59.496930

# %% [markdown]
# ##### *Concat training and validation subsets in a single set*

# %%
# concat training and validation subsets
# to use them both as a single set to train the baseline models
x_train_concat = np.concatenate((x_train_svd, x_valid_svd))
y_train_concat = np.concatenate((y_train, y_valid))

# pass the values in a dictionary
sets = {'train': [x_train_concat, y_train_concat], 'test': [x_test_svd, y_test]}

# %% [markdown]
# ## Baseline Results <a class='anchor' id='baseline_results'></a>
#
# ##### *Run experimental results using:*
#
# - Baseline dummy classifier
# - Best performing classifier from [*text_classification_with_basic_models*](https://github.com/sapaladas/text_classification_with_basic_models) repository

# %%
def calculate_metrics(sets):
    
    # list of classifiers
    models = [['DummyClassifier', DummyClassifier(strategy='most_frequent', random_state=1)],
              ['LogisticRegression', LogisticRegression(C=0.97, max_iter=300, random_state=1)]]

    # loop through classifiers
    for i, (name, model) in enumerate(models):
        
        print('='*117)

        # loop through train and test sets
        for j, (key, values) in enumerate(sets.items()):

            print(f'# {i+1} - {name} ({key} set)\n' + '-'*60)

            # fit the model in the train set
            if key == 'train':
                clf = model.fit(values[0], values[1])
            
            # predict
            preds = clf.predict(values[0])

            # classification report
            target_names = ['Negative Review (0)', 'Positive Review (1)']
            class_report = classification_report(values[1], preds, labels=np.unique(values[1]), target_names=target_names)
            print(class_report)

            # only for test set
            if j != 0:
                
                # create figure
                fig = plt.figure(figsize=(12,4),dpi=100,facecolor='white')

                # compute and plot the confusion matrix
                ax1 = fig.add_subplot(121)
                conf_matrix = ConfusionMatrixDisplay.from_estimator(clf, values[0], values[1], ax=ax1)

                # compute and plot the precision recall auc curve
                preds_proba = clf.predict_proba(values[0])
                precision, recall, thresholds = precision_recall_curve(values[1], preds_proba[:,1])
                area = auc(recall, precision)
                
                ax2 = fig.add_subplot(122)
                ax2.plot(recall, precision)
                ax2.set_xlabel('Recall')
                ax2.set_ylabel('Precision')
                ax2.set_ylim([0.0, 1.05])
                ax2.set_xlim([0.0, 1.0])
                ax2.set_title(f'Precision-Recall - AUC = {area:.2}')
                fig.suptitle(f'{name}')
                plt.savefig(f'./images/auc_curves_{name}.svg')
                plt.show()

    return

# execute function
_ = calculate_metrics(sets)
# Out:
# =====================================================================================================================
# # 1 - DummyClassifier (train set)
# ------------------------------------------------------------
#                      precision    recall  f1-score   support
#
# Negative Review (0)       0.50      1.00      0.67     21250
# Positive Review (1)       0.00      0.00      0.00     21250
#
#            accuracy                           0.50     42500
#           macro avg       0.25      0.50      0.33     42500
#        weighted avg       0.25      0.50      0.33     42500
#
# # 1 - DummyClassifier (test set)
# ------------------------------------------------------------
#                      precision    recall  f1-score   support
#
# Negative Review (0)       0.50      1.00      0.67      3750
# Positive Review (1)       0.00      0.00      0.00      3750
#
#            accuracy                           0.50      7500
#           macro avg       0.25      0.50      0.33      7500
#        weighted avg       0.25      0.50      0.33      7500
# =====================================================================================================================
# # 2 - LogisticRegression (train set)
# ------------------------------------------------------------
#                      precision    recall  f1-score   support
#
# Negative Review (0)       0.91      0.89      0.90     21250
# Positive Review (1)       0.89      0.91      0.90     21250
#
#            accuracy                           0.90     42500
#           macro avg       0.90      0.90      0.90     42500
#        weighted avg       0.90      0.90      0.90     42500
#
# # 2 - LogisticRegression (test set)
# ------------------------------------------------------------
#                      precision    recall  f1-score   support
#
# Negative Review (0)       0.90      0.88      0.89      3750
# Positive Review (1)       0.88      0.90      0.89      3750
#
#            accuracy                           0.89      7500
#           macro avg       0.89      0.89      0.89      7500
#        weighted avg       0.89      0.89      0.89      7500

# %% [markdown]
# ## MLP Hyperparameter Tuning <a class='anchor' id='tuning'></a>
#
# - Before we train the MLP model, we want to optimize some of the hyperparameters
# - We will tune the hyperparameters using the ***validation*** set
# - Specifically, we will define a grid and try to tune the ***number of hidden layers***, the ***number of neurons*** and the ***dropout rate***
# - We will use a `RandomizedSearchCV` function along with a $5$-fold stratified cross validation
# - Finally, we will evaluate the scores obtained from cross validation using the ***F1-Score*** metric
#
# ##### *Define function to tune MLP's hyperparameters*

# %%
def hyperparameter_tuning(x_valid, y_valid):

    # hyperparameters to test
    hidden_layers = [2,4,6]
    neurons = [128,256,512]
    dropout_rate = [0.2,0.5]

    # create the param grid
    param_grid = dict(hidden_layers=hidden_layers, neurons=neurons, dropout_rate=dropout_rate)

    def build_model(hidden_layers, neurons, dropout_rate):
        """
        Function to build a sequential MLP model.
        Inputs:
          - Number of hidden layers
          - Number of neurons in the first layer
          - Dropout rate
        Outputs:
          - MLP model
        """
        # initialize model
        model = Sequential()
        
        # loop to add N number of hidden layers
        for i in range(hidden_layers):
            
            if i == 0:
                # create first hidden layer with input dimensions
                model.add(Dense(neurons, input_dim=x_valid.shape[1], activation='relu'))
                model.add(Dropout(dropout_rate))
                neurons = neurons / 2
                
            else:
                # create next hidden layer
                model.add(Dense(neurons, activation='relu'))
                model.add(Dropout(dropout_rate))
                neurons = neurons / 2
                
        # output layer
        model.add(Dense(1, activation='sigmoid'))
        model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])
        return model

    # initialize the keras model
    model = KerasClassifier(build_fn=build_model, epochs=100, batch_size=250, verbose=0)

    # RandomizedSearchCV
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)
    rs = RandomizedSearchCV(estimator=model, param_distributions=param_grid, scoring='f1', cv=cv, random_state=1, verbose=1, n_jobs=-1)
    rs.fit(x_valid, y_valid)

    # evaluate
    best_score = rs.best_score_
    best_params = rs.best_params_

    # print results
    print(f'Best grid score: {best_score}')
    print(f'Best grid params: {best_params}', end='\n\n')

    return None

# starting time
start_time = datetime.now()

# execute function
_ = hyperparameter_tuning(x_valid_svd, y_valid)

# ending time
end_time = datetime.now()

print(f'Elapsed time: {end_time - start_time}')
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best grid score: 0.8455722843576403
# Best grid params: {'neurons': 256, 'hidden_layers': 4, 'dropout_rate': 0.5}
#
# Elapsed time: 0:27:00.818101

# %% [markdown]
# ## Classification Results <a class='anchor' id='results'></a>
#
# - The next step is to train the MLP model using the best hyperparameters we obtained during tuning
# - We will use `ModelCheckpoint` callback to find and save the best weights for our model, monitoring the ***F1-Score*** metric
# - Then, we will plot the curves showing the *accuracy* and *loss* on training data as a *function of epochs*
# - Finally, we will evaluate the performance of the MLP model in the ***test*** set and plot the *Confusion Matrices* and the *Precision-Recall AUC Curves*
#
# ##### *Define custom Keras callback for calculating precision, recall, F1 at the end of each epoch*

# %%
class Metrics(tf.keras.callbacks.Callback):
    def __init__(self, valid_data):
        super(Metrics, self).__init__()
        self.validation_data = valid_data

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        val_predict = np.argmax(self.model.predict(self.validation_data[0]), -1)
        val_targ = self.validation_data[1]
        val_targ = tf.cast(val_targ, dtype=tf.float32)
        if len(val_targ.shape) == 2 and val_targ.shape[1] != 1:
            val_targ = np.argmax(val_targ, -1)      
        
        _val_precision = precision_score(val_targ, val_predict, average='weighted')
        _val_recall = recall_score(val_targ, val_predict, average='weighted')
        _val_f1 = f1_score(val_targ, val_predict, average='weighted')

        logs['val_precision'] = _val_precision
        logs['val_recall'] = _val_recall
        logs['val_f1'] = _val_f1
        print(f' - val_precision: {_val_precision} - val_recall: {_val_recall} - val_f1: {_val_f1}')
        return

# %% [markdown]
# ##### *Train the MLP classifier*

# %%
with tf.device('/device:GPU:0'):

    # build the MLP model 
    # using the best hyperparameters obtained from the previous step
    model = Sequential()
    model.add(Dense(256, input_dim=x_train_concat.shape[1], activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))

    print(model.summary())
    model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

    if not os.path.exists('./checkpoints'):
        os.makedirs('./checkpoints')

    checkpoint = ModelCheckpoint('checkpoints/weights.hdf5',
                                 monitor='val_loss',
                                 mode='min',
                                 verbose=2,
                                 save_best_only=True,
                                 save_weights_only=True)
    
    history = model.fit(x_train_concat,
                        y_train_concat,
                        validation_data=(x_test_svd, y_test),
                        batch_size=250,
                        epochs=100,
                        shuffle=True,
                        callbacks=[Metrics(valid_data=(x_test_svd, y_test)), checkpoint])
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_76 (Dense)            (None, 256)               512256
#
#  dropout_41 (Dropout)        (None, 256)               0
#
#  dense_77 (Dense)            (None, 128)               32896
#
#  dropout_42 (Dropout)        (None, 128)               0
#
#  dense_78 (Dense)            (None, 64)                8256
#
#  dropout_43 (Dropout)        (None, 64)                0
#
#  dense_79 (Dense)            (None, 32)                2080
#
#  dropout_44 (Dropout)        (None, 32)                0
#
#  dense_80 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 555,521
# Trainable params: 555,521
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 167/170 [============================>.] - ETA: 0s - loss: 0.5250 - accuracy: 0.7216 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00001: val_loss improved from inf to 0.28694, saving model to checkpoints/weights.hdf5
# 170/170 [==============================] - 2s 9ms/step - loss: 0.5218 - accuracy: 0.7240 - val_loss: 0.2869 - val_accuracy: 0.8807 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 2/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.2941 - accuracy: 0.8855 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00002: val_loss improved from 0.28694 to 0.26950, saving model to checkpoints/weights.hdf5
# 170/170 [==============================] - 1s 8ms/step - loss: 0.2942 - accuracy: 0.8854 - val_loss: 0.2695 - val_accuracy: 0.8880 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 3/100
# 165/170 [============================>.] - ETA: 0s - loss: 0.2459 - accuracy: 0.9087 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00003: val_loss did not improve from 0.26950
# 170/170 [==============================] - 1s 9ms/step - loss: 0.2452 - accuracy: 0.9087 - val_loss: 0.2729 - val_accuracy: 0.8877 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 4/100
# 164/170 [===========================>..] - ETA: 0s - loss: 0.1919 - accuracy: 0.9313 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00004: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.1926 - accuracy: 0.9311 - val_loss: 0.2819 - val_accuracy: 0.8899 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 5/100
# 166/170 [============================>.] - ETA: 0s - loss: 0.1486 - accuracy: 0.9506 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00005: val_loss did not improve from 0.26950
# 170/170 [==============================] - 1s 9ms/step - loss: 0.1488 - accuracy: 0.9504 - val_loss: 0.3185 - val_accuracy: 0.8837 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 6/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.1083 - accuracy: 0.9638 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00006: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.1083 - accuracy: 0.9637 - val_loss: 0.3427 - val_accuracy: 0.8887 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 7/100
# 168/170 [============================>.] - ETA: 0s - loss: 0.0839 - accuracy: 0.9735 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00007: val_loss did not improve from 0.26950
# 170/170 [==============================] - 1s 8ms/step - loss: 0.0843 - accuracy: 0.9734 - val_loss: 0.3866 - val_accuracy: 0.8812 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 8/100
# 167/170 [============================>.] - ETA: 0s - loss: 0.0668 - accuracy: 0.9773 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00008: val_loss did not improve from 0.26950
# 170/170 [==============================] - 1s 9ms/step - loss: 0.0669 - accuracy: 0.9773 - val_loss: 0.4277 - val_accuracy: 0.8833 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 9/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0565 - accuracy: 0.9814 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00009: val_loss did not improve from 0.26950
# 170/170 [==============================] - 1s 9ms/step - loss: 0.0566 - accuracy: 0.9813 - val_loss: 0.4766 - val_accuracy: 0.8852 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 10/100
# 165/170 [============================>.] - ETA: 0s - loss: 0.0486 - accuracy: 0.9849 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00010: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0490 - accuracy: 0.9847 - val_loss: 0.4822 - val_accuracy: 0.8840 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 11/100
# 164/170 [===========================>..] - ETA: 0s - loss: 0.0445 - accuracy: 0.9849 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00011: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0446 - accuracy: 0.9848 - val_loss: 0.4727 - val_accuracy: 0.8833 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 12/100
# 166/170 [============================>.] - ETA: 0s - loss: 0.0387 - accuracy: 0.9872 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00012: val_loss did not improve from 0.26950
# 170/170 [==============================] - 1s 9ms/step - loss: 0.0388 - accuracy: 0.9871 - val_loss: 0.4975 - val_accuracy: 0.8843 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 13/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0367 - accuracy: 0.9884 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00013: val_loss did not improve from 0.26950
# 170/170 [==============================] - 1s 8ms/step - loss: 0.0366 - accuracy: 0.9884 - val_loss: 0.5305 - val_accuracy: 0.8844 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 14/100
# 168/170 [============================>.] - ETA: 0s - loss: 0.0340 - accuracy: 0.9893 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00014: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0343 - accuracy: 0.9892 - val_loss: 0.5410 - val_accuracy: 0.8859 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 15/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0318 - accuracy: 0.9895 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00015: val_loss did not improve from 0.26950
# 170/170 [==============================] - 1s 8ms/step - loss: 0.0318 - accuracy: 0.9895 - val_loss: 0.5577 - val_accuracy: 0.8843 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 16/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0294 - accuracy: 0.9910 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00016: val_loss did not improve from 0.26950
# 170/170 [==============================] - 1s 8ms/step - loss: 0.0294 - accuracy: 0.9909 - val_loss: 0.5452 - val_accuracy: 0.8852 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 17/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0264 - accuracy: 0.9918 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00017: val_loss did not improve from 0.26950
# 170/170 [==============================] - 1s 8ms/step - loss: 0.0267 - accuracy: 0.9918 - val_loss: 0.6109 - val_accuracy: 0.8819 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 18/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0283 - accuracy: 0.9911 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00018: val_loss did not improve from 0.26950
# 170/170 [==============================] - 1s 9ms/step - loss: 0.0284 - accuracy: 0.9910 - val_loss: 0.5892 - val_accuracy: 0.8837 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 19/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0259 - accuracy: 0.9914 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00019: val_loss did not improve from 0.26950
# 170/170 [==============================] - 1s 8ms/step - loss: 0.0257 - accuracy: 0.9914 - val_loss: 0.6168 - val_accuracy: 0.8844 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 20/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0250 - accuracy: 0.9921 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00020: val_loss did not improve from 0.26950
# 170/170 [==============================] - 1s 9ms/step - loss: 0.0250 - accuracy: 0.9921 - val_loss: 0.6118 - val_accuracy: 0.8837 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 21/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0235 - accuracy: 0.9928 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00021: val_loss did not improve from 0.26950
# 170/170 [==============================] - 1s 9ms/step - loss: 0.0235 - accuracy: 0.9928 - val_loss: 0.6281 - val_accuracy: 0.8863 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 22/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0235 - accuracy: 0.9929 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00022: val_loss did not improve from 0.26950
# 170/170 [==============================] - 1s 9ms/step - loss: 0.0234 - accuracy: 0.9929 - val_loss: 0.6595 - val_accuracy: 0.8855 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 23/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0234 - accuracy: 0.9930 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00023: val_loss did not improve from 0.26950
# 170/170 [==============================] - 1s 9ms/step - loss: 0.0235 - accuracy: 0.9930 - val_loss: 0.6105 - val_accuracy: 0.8867 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 24/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0202 - accuracy: 0.9935 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00024: val_loss did not improve from 0.26950
# 170/170 [==============================] - 1s 9ms/step - loss: 0.0202 - accuracy: 0.9935 - val_loss: 0.6626 - val_accuracy: 0.8860 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 25/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0223 - accuracy: 0.9929 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00025: val_loss did not improve from 0.26950
# 170/170 [==============================] - 1s 9ms/step - loss: 0.0224 - accuracy: 0.9929 - val_loss: 0.6459 - val_accuracy: 0.8824 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 26/100
# 168/170 [============================>.] - ETA: 0s - loss: 0.0203 - accuracy: 0.9936 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00026: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0203 - accuracy: 0.9936 - val_loss: 0.6556 - val_accuracy: 0.8828 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 27/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0209 - accuracy: 0.9934 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00027: val_loss did not improve from 0.26950
# 170/170 [==============================] - 1s 9ms/step - loss: 0.0210 - accuracy: 0.9934 - val_loss: 0.6647 - val_accuracy: 0.8820 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 28/100
# 167/170 [============================>.] - ETA: 0s - loss: 0.0208 - accuracy: 0.9931 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00028: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0208 - accuracy: 0.9931 - val_loss: 0.6738 - val_accuracy: 0.8812 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 29/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0205 - accuracy: 0.9933 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00029: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0204 - accuracy: 0.9934 - val_loss: 0.6645 - val_accuracy: 0.8839 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 30/100
# 165/170 [============================>.] - ETA: 0s - loss: 0.0175 - accuracy: 0.9944 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00030: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 11ms/step - loss: 0.0176 - accuracy: 0.9943 - val_loss: 0.7101 - val_accuracy: 0.8819 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 31/100
# 165/170 [============================>.] - ETA: 0s - loss: 0.0179 - accuracy: 0.9944 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00031: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0178 - accuracy: 0.9944 - val_loss: 0.6795 - val_accuracy: 0.8844 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 32/100
# 166/170 [============================>.] - ETA: 0s - loss: 0.0194 - accuracy: 0.9939 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00032: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0195 - accuracy: 0.9939 - val_loss: 0.7058 - val_accuracy: 0.8829 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 33/100
# 168/170 [============================>.] - ETA: 0s - loss: 0.0176 - accuracy: 0.9945 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00033: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0177 - accuracy: 0.9944 - val_loss: 0.7281 - val_accuracy: 0.8856 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 34/100
# 164/170 [===========================>..] - ETA: 0s - loss: 0.0179 - accuracy: 0.9947 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00034: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0176 - accuracy: 0.9948 - val_loss: 0.7016 - val_accuracy: 0.8828 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 35/100
# 167/170 [============================>.] - ETA: 0s - loss: 0.0165 - accuracy: 0.9942 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00035: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0163 - accuracy: 0.9943 - val_loss: 0.7325 - val_accuracy: 0.8827 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 36/100
# 166/170 [============================>.] - ETA: 0s - loss: 0.0162 - accuracy: 0.9949 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00036: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0164 - accuracy: 0.9948 - val_loss: 0.7563 - val_accuracy: 0.8848 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 37/100
# 165/170 [============================>.] - ETA: 0s - loss: 0.0185 - accuracy: 0.9938 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00037: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0184 - accuracy: 0.9938 - val_loss: 0.7361 - val_accuracy: 0.8856 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 38/100
# 167/170 [============================>.] - ETA: 0s - loss: 0.0159 - accuracy: 0.9947 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00038: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.7562 - val_accuracy: 0.8851 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 39/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0150 - accuracy: 0.9948 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00039: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0149 - accuracy: 0.9948 - val_loss: 0.8003 - val_accuracy: 0.8816 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 40/100
# 166/170 [============================>.] - ETA: 0s - loss: 0.0166 - accuracy: 0.9954 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00040: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0163 - accuracy: 0.9955 - val_loss: 0.7209 - val_accuracy: 0.8819 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 41/100
# 165/170 [============================>.] - ETA: 0s - loss: 0.0149 - accuracy: 0.9952 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00041: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0151 - accuracy: 0.9951 - val_loss: 0.7200 - val_accuracy: 0.8821 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 42/100
# 164/170 [===========================>..] - ETA: 0s - loss: 0.0162 - accuracy: 0.9953 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00042: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0160 - accuracy: 0.9954 - val_loss: 0.7674 - val_accuracy: 0.8845 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 43/100
# 164/170 [===========================>..] - ETA: 0s - loss: 0.0160 - accuracy: 0.9954 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00043: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0157 - accuracy: 0.9955 - val_loss: 0.7260 - val_accuracy: 0.8816 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 44/100
# 164/170 [===========================>..] - ETA: 0s - loss: 0.0168 - accuracy: 0.9951 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00044: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0170 - accuracy: 0.9951 - val_loss: 0.6980 - val_accuracy: 0.8827 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 45/100
# 170/170 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9948 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00045: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0165 - accuracy: 0.9948 - val_loss: 0.6748 - val_accuracy: 0.8819 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 46/100
# 170/170 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9955 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00046: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0146 - accuracy: 0.9955 - val_loss: 0.7638 - val_accuracy: 0.8795 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 47/100
# 164/170 [===========================>..] - ETA: 0s - loss: 0.0161 - accuracy: 0.9949 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00047: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0160 - accuracy: 0.9949 - val_loss: 0.7202 - val_accuracy: 0.8843 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 48/100
# 164/170 [===========================>..] - ETA: 0s - loss: 0.0163 - accuracy: 0.9950 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00048: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0161 - accuracy: 0.9949 - val_loss: 0.7068 - val_accuracy: 0.8844 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 49/100
# 164/170 [===========================>..] - ETA: 0s - loss: 0.0149 - accuracy: 0.9949 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00049: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0148 - accuracy: 0.9950 - val_loss: 0.7945 - val_accuracy: 0.8840 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 50/100
# 170/170 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9955 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00050: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0150 - accuracy: 0.9955 - val_loss: 0.8039 - val_accuracy: 0.8832 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 51/100
# 167/170 [============================>.] - ETA: 0s - loss: 0.0118 - accuracy: 0.9964 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00051: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0120 - accuracy: 0.9964 - val_loss: 0.8162 - val_accuracy: 0.8873 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 52/100
# 170/170 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9958 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00052: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0142 - accuracy: 0.9958 - val_loss: 0.8290 - val_accuracy: 0.8831 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 53/100
# 170/170 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9954 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00053: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 9ms/step - loss: 0.0157 - accuracy: 0.9954 - val_loss: 0.7754 - val_accuracy: 0.8828 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 54/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0152 - accuracy: 0.9954 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00054: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0152 - accuracy: 0.9954 - val_loss: 0.7651 - val_accuracy: 0.8812 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 55/100
# 170/170 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9960 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00055: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0134 - accuracy: 0.9960 - val_loss: 0.7492 - val_accuracy: 0.8824 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 56/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0135 - accuracy: 0.9956 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00056: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0135 - accuracy: 0.9956 - val_loss: 0.7693 - val_accuracy: 0.8843 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 57/100
# 168/170 [============================>.] - ETA: 0s - loss: 0.0146 - accuracy: 0.9959 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00057: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0146 - accuracy: 0.9959 - val_loss: 0.7475 - val_accuracy: 0.8864 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 58/100
# 170/170 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9959 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00058: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0130 - accuracy: 0.9959 - val_loss: 0.7429 - val_accuracy: 0.8859 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 59/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0139 - accuracy: 0.9962 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00059: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0139 - accuracy: 0.9962 - val_loss: 0.7833 - val_accuracy: 0.8861 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 60/100
# 168/170 [============================>.] - ETA: 0s - loss: 0.0131 - accuracy: 0.9960 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00060: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0130 - accuracy: 0.9960 - val_loss: 0.7534 - val_accuracy: 0.8869 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 61/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0122 - accuracy: 0.9966 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00061: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0122 - accuracy: 0.9965 - val_loss: 0.7990 - val_accuracy: 0.8859 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 62/100
# 170/170 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9962 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00062: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0118 - accuracy: 0.9962 - val_loss: 0.8523 - val_accuracy: 0.8840 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 63/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0133 - accuracy: 0.9961 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00063: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0133 - accuracy: 0.9961 - val_loss: 0.7664 - val_accuracy: 0.8876 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 64/100
# 167/170 [============================>.] - ETA: 0s - loss: 0.0128 - accuracy: 0.9966 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00064: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0128 - accuracy: 0.9966 - val_loss: 0.7312 - val_accuracy: 0.8872 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 65/100
# 165/170 [============================>.] - ETA: 0s - loss: 0.0123 - accuracy: 0.9962 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00065: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0122 - accuracy: 0.9962 - val_loss: 0.7254 - val_accuracy: 0.8852 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 66/100
# 170/170 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9963 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00066: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0117 - accuracy: 0.9963 - val_loss: 0.7856 - val_accuracy: 0.8876 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 67/100
# 168/170 [============================>.] - ETA: 0s - loss: 0.0132 - accuracy: 0.9963 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00067: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0133 - accuracy: 0.9962 - val_loss: 0.7707 - val_accuracy: 0.8876 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 68/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0126 - accuracy: 0.9959 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00068: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.7793 - val_accuracy: 0.8893 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 69/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0111 - accuracy: 0.9963 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00069: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0113 - accuracy: 0.9963 - val_loss: 0.8008 - val_accuracy: 0.8909 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 70/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0119 - accuracy: 0.9963 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00070: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.8166 - val_accuracy: 0.8867 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 71/100
# 168/170 [============================>.] - ETA: 0s - loss: 0.0126 - accuracy: 0.9962 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00071: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0127 - accuracy: 0.9961 - val_loss: 0.7504 - val_accuracy: 0.8903 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 72/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0105 - accuracy: 0.9969 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00072: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0105 - accuracy: 0.9969 - val_loss: 0.8488 - val_accuracy: 0.8872 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 73/100
# 168/170 [============================>.] - ETA: 0s - loss: 0.0128 - accuracy: 0.9960 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00073: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0127 - accuracy: 0.9960 - val_loss: 0.7706 - val_accuracy: 0.8864 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 74/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0111 - accuracy: 0.9964 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00074: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0112 - accuracy: 0.9964 - val_loss: 0.8636 - val_accuracy: 0.8869 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 75/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0105 - accuracy: 0.9966 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00075: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0105 - accuracy: 0.9966 - val_loss: 0.8831 - val_accuracy: 0.8840 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 76/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0092 - accuracy: 0.9969 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00076: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0092 - accuracy: 0.9969 - val_loss: 0.8559 - val_accuracy: 0.8821 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 77/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0108 - accuracy: 0.9965 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00077: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 0.8247 - val_accuracy: 0.8860 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 78/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0119 - accuracy: 0.9962 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00078: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0119 - accuracy: 0.9962 - val_loss: 0.7456 - val_accuracy: 0.8852 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 79/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0113 - accuracy: 0.9965 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00079: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0112 - accuracy: 0.9965 - val_loss: 0.8330 - val_accuracy: 0.8863 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 80/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0125 - accuracy: 0.9961 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00080: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0125 - accuracy: 0.9961 - val_loss: 0.8179 - val_accuracy: 0.8853 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 81/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0112 - accuracy: 0.9968 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00081: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0112 - accuracy: 0.9968 - val_loss: 0.8441 - val_accuracy: 0.8879 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 82/100
# 168/170 [============================>.] - ETA: 0s - loss: 0.0114 - accuracy: 0.9963 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00082: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0114 - accuracy: 0.9964 - val_loss: 0.8078 - val_accuracy: 0.8852 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 83/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0108 - accuracy: 0.9969 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00083: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0108 - accuracy: 0.9969 - val_loss: 0.8035 - val_accuracy: 0.8812 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 84/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0107 - accuracy: 0.9964 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00084: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0107 - accuracy: 0.9965 - val_loss: 0.8310 - val_accuracy: 0.8851 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 85/100
# 167/170 [============================>.] - ETA: 0s - loss: 0.0107 - accuracy: 0.9966 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00085: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.8400 - val_accuracy: 0.8869 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 86/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0098 - accuracy: 0.9970 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00086: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0098 - accuracy: 0.9971 - val_loss: 0.8021 - val_accuracy: 0.8856 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 87/100
# 165/170 [============================>.] - ETA: 0s - loss: 0.0116 - accuracy: 0.9963 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00087: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 11ms/step - loss: 0.0116 - accuracy: 0.9963 - val_loss: 0.8746 - val_accuracy: 0.8863 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 88/100
# 168/170 [============================>.] - ETA: 0s - loss: 0.0100 - accuracy: 0.9971 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00088: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0099 - accuracy: 0.9971 - val_loss: 0.8258 - val_accuracy: 0.8872 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 89/100
# 167/170 [============================>.] - ETA: 0s - loss: 0.0102 - accuracy: 0.9972 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00089: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0105 - accuracy: 0.9971 - val_loss: 0.8354 - val_accuracy: 0.8840 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 90/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0106 - accuracy: 0.9969 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00090: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 11ms/step - loss: 0.0108 - accuracy: 0.9968 - val_loss: 0.7957 - val_accuracy: 0.8832 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 91/100
# 168/170 [============================>.] - ETA: 0s - loss: 0.0081 - accuracy: 0.9972 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00091: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.9049 - val_accuracy: 0.8847 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 92/100
# 164/170 [===========================>..] - ETA: 0s - loss: 0.0078 - accuracy: 0.9975 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00092: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0078 - accuracy: 0.9975 - val_loss: 0.9096 - val_accuracy: 0.8853 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 93/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0098 - accuracy: 0.9972 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00093: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0098 - accuracy: 0.9972 - val_loss: 0.8389 - val_accuracy: 0.8849 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 94/100
# 168/170 [============================>.] - ETA: 0s - loss: 0.0096 - accuracy: 0.9970 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00094: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0096 - accuracy: 0.9970 - val_loss: 0.8756 - val_accuracy: 0.8844 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 95/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0092 - accuracy: 0.9972 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00095: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0092 - accuracy: 0.9972 - val_loss: 0.9157 - val_accuracy: 0.8856 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 96/100
# 164/170 [===========================>..] - ETA: 0s - loss: 0.0103 - accuracy: 0.9966 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00096: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.8439 - val_accuracy: 0.8859 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 97/100
# 169/170 [============================>.] - ETA: 0s - loss: 0.0095 - accuracy: 0.9973 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00097: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0095 - accuracy: 0.9973 - val_loss: 0.8658 - val_accuracy: 0.8892 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 98/100
# 167/170 [============================>.] - ETA: 0s - loss: 0.0109 - accuracy: 0.9967 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00098: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 0.7569 - val_accuracy: 0.8867 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 99/100
# 168/170 [============================>.] - ETA: 0s - loss: 0.0107 - accuracy: 0.9970 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00099: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0107 - accuracy: 0.9971 - val_loss: 0.7254 - val_accuracy: 0.8845 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333
# Epoch 100/100
# 167/170 [============================>.] - ETA: 0s - loss: 0.0093 - accuracy: 0.9972 - val_precision: 0.25 - val_recall: 0.5 - val_f1: 0.3333333333333333
#
# Epoch 00100: val_loss did not improve from 0.26950
# 170/170 [==============================] - 2s 10ms/step - loss: 0.0092 - accuracy: 0.9973 - val_loss: 0.8533 - val_accuracy: 0.8876 - val_precision: 0.2500 - val_recall: 0.5000 - val_f1: 0.3333

# %% [markdown]
# ##### *Plot the curves showing the accuracy and loss on training data as a function of epochs*

# %%
# create the figure
fig, ax = plt.subplots(1,2,figsize=(12,6),dpi=100,facecolor='white')

# plot the accuracy
ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].set_title('MLP Accuracy')
ax[0].legend(['training data', 'validation data'], loc='upper left')

# plot the loss
ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('MLP Loss')
ax[1].legend(['training data', 'validation data'], loc='upper left')

plt.tight_layout(pad=5)
plt.savefig('./images/MLP_accuracy_loss_curves.svg')
plt.show()

# %% [markdown]
# ##### *Evaluate the performance of the MLP model*

# %%
with tf.device('/device:GPU:0'):
    
    model = Sequential()
    model.add(Dense(256, input_dim=x_train_concat.shape[1], activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    # load weights from the pre-trained model
    model.load_weights('checkpoints/weights.hdf5')
    model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

    # loop through train and test sets
    for j, (key, values) in enumerate(sets.items()):

        print(f'# 3 - MLP ({key} set)\n' + '-'*60)
            
        # predict
        preds = np.where(model.predict(values[0]) > 0.5, 1, 0)

        # classification report
        target_names = ['Negative Review (0)', 'Positive Review (1)']
        class_report = classification_report(values[1], preds, labels=np.unique(values[1]), target_names=target_names)
        print(class_report)

        # only for test set
        if j != 0:
            
            # create figure
            fig = plt.figure(figsize=(12,4),dpi=100,facecolor='white')
            
            # compute and plot the confusion matrix
            ax1 = fig.add_subplot(121)
            conf_matrix = ConfusionMatrixDisplay.from_predictions(values[1], preds, ax=ax1)
            
            # compute the area under curve
            precision, recall, thresholds = precision_recall_curve(values[1], preds)
            area = auc(recall, precision)
            # plot the area under curve
            ax2 = fig.add_subplot(122)
            ax2.plot(recall, precision)
            ax2.set_xlabel('Recall')
            ax2.set_ylabel('Precision')
            ax2.set_ylim([0.0, 1.05])
            ax2.set_xlim([0.0, 1.0])
            ax2.set_title(f'Precision-Recall - AUC = {area:.2}')
            fig.suptitle('Multi-Layer Perceptron (MLP)')
            plt.savefig(f'./images/auc_curves_MLP.svg')
            plt.show()
# Out:
# # 3 - MLP (train set)
# ------------------------------------------------------------
#                      precision    recall  f1-score   support
#
# Negative Review (0)       0.94      0.91      0.92     21250
# Positive Review (1)       0.91      0.94      0.93     21250
#
#            accuracy                           0.92     42500
#           macro avg       0.93      0.92      0.92     42500
#        weighted avg       0.93      0.92      0.92     42500
#
# # 3 - MLP (test set)
# ------------------------------------------------------------
#                      precision    recall  f1-score   support
#
# Negative Review (0)       0.90      0.87      0.89      3750
# Positive Review (1)       0.88      0.90      0.89      3750
#
#            accuracy                           0.89      7500
#           macro avg       0.89      0.89      0.89      7500
#        weighted avg       0.89      0.89      0.89      7500

# %% [markdown]
# ---
#
# *Thank you!*
#
# ---
